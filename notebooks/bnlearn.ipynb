# %% [markdown]
# <a href="https://colab.research.google.com/github/L00NE/loone_tmp_scripts/blob/main/notebooks/bnlearn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href='https://erdogant.medium.com/membership' target='_blank'><img height='200' style='border:0px;height:36px;' src='https://erdogant.github.io/bnlearn/pages/html/_images/logo.png' border='0' alt='Follow me on Medium' /></a>
#
# # Bnlearn for Python
#
# Welcome to the notebook of **bnlearn**. bnlearn is Python package for learning the graphical structure of Bayesian networks, parameter learning, inference and sampling methods. Because probabilistic graphical models can be difficult in usage, Bnlearn for python (this package) is build on the pgmpy package and contains the most-wanted pipelines. Navigate to API documentations for more detailed information.
#
# The core functionalities are:
# <br>
# <b>* Causal Discovery</b>
# <br>
# <b>* Structure Learning</b>
# <br>
# <b>* Parameter Learning</b>
# <br>
# <b>* Inferences using do-calculus</b>
# <br>
# <br>
#
# ---
#
# ## Read the Medium blog for more detailed information.
#
# #### [1. A Step-by-Step Guide in detecting causal relationships using Bayesian Structure Learning in Python](https://towardsdatascience.com/a-step-by-step-guide-in-detecting-causal-relationships-using-bayesian-structure-learning-in-python-c20c6b31cee5)
#
#
# #### [2. A step-by-step guide in designing knowledge-driven models using Bayesian theorem.](https://towardsdatascience.com/a-step-by-step-guide-in-designing-knowledge-driven-models-using-bayesian-theorem-7433f6fd64be)
#
# #### [3. The Power of Bayesian Causal Inference: A Comparative Analysis of Libraries to Reveal Hidden Causality in Your Dataset.](https://towardsdatascience.com/the-power-of-bayesian-causal-inference-a-comparative-analysis-of-libraries-to-reveal-hidden-d91e8306e25e)
#
# #### [4. Chat with Your Dataset using Bayesian Inferences.](https://towardsdatascience.com/chat-with-your-dataset-using-bayesian-inferences-bfd4dc7f8dcd)
#
#
#
#
#
# <br>
#
# ---
#
#
# ## Github
# * [Github](https://github.com/erdogant/bnlearn)
# * [Documentation pages](https://erdogant.github.io/bnlearn/)
#
# <br>
#
# ---
#
# ## Github
#
# <a href="https://colab.research.google.com/github/erdogant/bnlearn/blob/master/notebooks/bnlearn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# <br>
#
# ---
#
#
# ## Support
# This library runs on coffee :) You can [support](https://erdogant.github.io/pca/pages/html/Documentation.html) in various ways, have a look at the [sponser page](https://erdogant.github.io/pca/pages/html/Documentation.html). Report bugs, issues and feature extensions at [github page](https://github.com/erdogant/pca).
#
# <a href='https://www.buymeacoffee.com/erdogant' target='_blank'><img height='36' style='border:0px;height:36px;' src='https://cdn.ko-fi.com/cdn/kofi1.png?v=3' border='0' alt='Buy Me a Coffee at ko-fi.com' /></a>
# <a href='https://erdogant.medium.com/subscribe' target='_blank'><img height='50' style='border:0px;height:36px;' src='https://erdogant.github.io/images/medium_follow_me.jpg' border='0' alt='Follow me on Medium' /></a>
#
# ---

# %% [markdown]
# **Installation of libraries**

# %%
# Install bnlearn
# !pip install -U bnlearn

# Install d3blocks
# !pip install d3blocks

# Install from github source
#!pip install -U git+https://github.com/erdogant/bnlearn

# %%
# Version matplotlib should be >= 3.3.4
import matplotlib
print(matplotlib.__version__)

import pandas as pd
import numpy as np

# Version pgmpy should be >= 0.1.13
import pgmpy
print(pgmpy.__version__)

# Latest version bnlearn
import bnlearn as bn
print(bn.__version__)
# Out:
# 3.7.1
# 0.1.22
# 0.7.16

# %% [markdown]
# **Structure learning example**

# %%
# Example dataframe sprinkler_data.csv can be loaded with:
df = bn.import_example()
# df = pd.read_csv('sprinkler_data.csv')
model = bn.structure_learning.fit(df)

# %%
G = bn.plot(model)

# %%
# Set some colors to the edges and nodes
node_properties = bn.get_node_properties(model)
node_properties['Sprinkler']['node_color']='#FF0000'

edge_properties = bn.get_edge_properties(model)

edge_properties[('Cloudy', 'Rain')]['color']='#FF0000'
edge_properties[('Cloudy', 'Rain')]['weight']=5
# Out:
# [bnlearn] >Set node properties.
# [bnlearn] >Set edge properties.

# %%
G = bn.plot(model,
            node_properties=node_properties,
            edge_properties=edge_properties,
            interactive=True,
            params_interactive={'notebook':True})
# Out:
# [d3blocks] >INFO> Cleaning edge_properties and config parameters..
# [d3blocks] >INFO> Set directed=True to see the markers!
# [d3blocks] >INFO> Keep only edges with weight>0
# [d3blocks] >INFO> Number of unique nodes: 4
# [d3blocks] >INFO> Slider range is set to [0, 5]
# [d3blocks] >INFO> Write to path: [/tmp/tmp_fytyffi/d3graph.html]
# [d3blocks] >INFO> File already exists and will be overwritten: [/tmp/tmp_fytyffi/d3graph.html]
# [d3blocks] >INFO> Number of unique nodes: 4
# [d3blocks] >INFO> Keep only edges with weight>0
# [d3blocks] >INFO> Slider range is set to [0, 5]
# [d3blocks] >INFO> Write to path: [/tmp/tmpds_3ymwh/bnlearn_causal_network.html]
# [d3blocks] >INFO> File already exists and will be overwritten: [/tmp/tmpds_3ymwh/bnlearn_causal_network.html]

# %% [markdown]
# **Various methodtypes and scoringtypes**

# %%
model_hc_bic  = bn.structure_learning.fit(df, methodtype='hc', scoretype='bic')
model_hc_k2   = bn.structure_learning.fit(df, methodtype='hc', scoretype='k2')
model_hc_bdeu = bn.structure_learning.fit(df, methodtype='hc', scoretype='bdeu')
model_ex_bic  = bn.structure_learning.fit(df, methodtype='ex', scoretype='bic')
model_ex_k2   = bn.structure_learning.fit(df, methodtype='ex', scoretype='k2')
model_ex_bdeu = bn.structure_learning.fit(df, methodtype='ex', scoretype='bdeu')
model_ex_bdeu = bn.structure_learning.fit(df, methodtype='cl', root_node='Cloudy')

# %% [markdown]
# Parameter Learning

# %%
# Import dataframe
df = bn.import_example()
# As an example we set the CPD at False which returns an "empty" DAG
model = bn.import_DAG('sprinkler', CPD=False)
# Now we learn the parameters of the DAG using the df
model_update = bn.parameter_learning.fit(model, df)
# Make plot
#G = bn.plot(model_update)
G = bn.plot(model_update,
            interactive=True,
            params_interactive={'notebook':True, 'cdn_resources': 'remote'})

# %% [markdown]
# **Inferences**

# %%
model = bn.import_DAG('sprinkler')
q_1 = bn.inference.fit(model, variables=['Rain'], evidence={'Cloudy':1,'Sprinkler':0, 'Wet_Grass':1})
q_2 = bn.inference.fit(model, variables=['Rain'], evidence={'Cloudy':1})

# %%
print(dir(q_2))
print(q_2.df)

# %% [markdown]
# **Sampling**

# %%
model = bn.import_DAG('sprinkler')
df = bn.sampling(model, n=1000)

# %% [markdown]
# **Comparing networks**

# %%
# Load asia DAG
model = bn.import_DAG('asia')
# plot ground truth
G = bn.plot(model, interactive=False)
# Sampling
df = bn.sampling(model, n=10000)
# Structure learning of sampled dataset
model_sl = bn.structure_learning.fit(df, methodtype='hc', scoretype='bic')
# Plot based on structure learning of sampled data
bn.plot(model_sl, pos=G['pos'])

# Compare networks and make plot
bn.compare_networks(model, model_sl, pos=G['pos'])

# %% [markdown]
# **Loading example DAG files**
#
# Note that some of the CPDs do not add up to exactly 1. This will raise an error that needs to be fixed in the input file. As an example, the **asia** works correctly but when you try **pathfinder** throws the error: "*>Warning: CPD [Fault] does not add up to 1 but is: 1.00000003*". You need to make sure that it exactly sums up to 1.

# %%
bif_file= 'sprinkler'
bif_file= 'alarm'
bif_file= 'andes'
bif_file= 'asia'
#bif_file= 'pathfinder'
#bif_file= 'sachs'
#bif_file= 'miserables'
#bif_file= 'filepath/to/model.bif'

# Loading example dataset
model = bn.import_DAG(bif_file, verbose=1)

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ### Example to learn structure in dataset that start with source-target and the weights.
#
# The weights can be counts how often two edges were detected.

# %%
raw = bn.import_example('stormofswords')
# Convert raw data into sparse datamatrix
df = bn.vec2df(raw['source'], raw['target'], raw['weight'])

# %%
print(df.head())
# Out:
#    Aegon  Aemon  Aerys  Alliser  Amory  Anguy   Arya  Balon  Barristan  \
# 0  False   True  False    False  False  False  False  False      False
# 1  False   True  False    False  False  False  False  False      False
# 2  False   True  False    False  False  False  False  False      False
# 3  False   True  False    False  False  False  False  False      False
# 4  False   True  False    False  False  False  False  False      False
#
#    Belwas  ...  Tommen  Tyrion  Tywin    Val  Varys  Viserys  Walder  Walton  \
# 0   False  ...   False   False  False  False  False    False   False   False
# 1   False  ...   False   False  False  False  False    False   False   False
# 2   False  ...   False   False  False  False  False    False   False   False
# 3   False  ...   False   False  False  False  False    False   False   False
# 4   False  ...   False   False  False  False  False    False   False   False
#
#     Worm  Ygritte
# 0  False    False
# 1  False    False
# 2  False    False
# 3  False    False
# 4  False    False
#
# [5 rows x 107 columns]

# %%
# Make the actual Bayesian DAG
DAG = bn.make_DAG(list(zip(raw['source'], raw['target'])), verbose=0)
# Make plot
G=bn.plot(DAG,
          interactive=True,
          params_interactive={'notebook':True, 'cdn_resources': 'remote', 'filter_menu': True, 'select_menu': True})

# You will see that this is a huge network with hundreds of edges.
# Out:
# [d3blocks] >INFO> Cleaning edge_properties and config parameters..
# [d3blocks] >INFO> Set directed=True to see the markers!
# [d3blocks] >INFO> Keep only edges with weight>0
# [d3blocks] >INFO> Number of unique nodes: 107
# [d3blocks] >INFO> Slider range is set to [0, 1]
# [bnlearn] >Set node properties.
# [bnlearn] >Set edge properties.
# [d3blocks] >INFO> Write to path: [/tmp/tmpxbz8b3si/d3graph.html]
# [d3blocks] >INFO> File already exists and will be overwritten: [/tmp/tmpxbz8b3si/d3graph.html]
# [d3blocks] >INFO> Number of unique nodes: 107
# [d3blocks] >INFO> Keep only edges with weight>0
# [d3blocks] >INFO> Slider range is set to [0, 1]
# [d3blocks] >INFO> Write to path: [/tmp/tmphtv67_ed/bnlearn_causal_network.html]
# [d3blocks] >INFO> File already exists and will be overwritten: [/tmp/tmphtv67_ed/bnlearn_causal_network.html]

# %%
# Parameter learning
model = bn.parameter_learning.fit(DAG, df, verbose=3)
# All the CPDs are now learned
# Out:
# [bnlearn] >Parameter learning> Computing parameters using [bayes]
# [bnlearn] >CPD of Aemon:
# +--------------+-----+---------------+
# | Jon          | ... | Jon(True)     |
# +--------------+-----+---------------+
# | Robert       | ... | Robert(True)  |
# +--------------+-----+---------------+
# | Stannis      | ... | Stannis(True) |
# +--------------+-----+---------------+
# | Aemon(False) | ... | 0.5           |
# +--------------+-----+---------------+
# | Aemon(True)  | ... | 0.5           |
# +--------------+-----+---------------+
# [bnlearn] >CPD of Grenn:
# +--------------+-----+----------------+---------------+
# | Aemon        | ... | Aemon(True)    | Aemon(True)   |
# +--------------+-----+----------------+---------------+
# | Eddison      | ... | Eddison(True)  | Eddison(True) |
# +--------------+-----+----------------+---------------+
# | Jon          | ... | Jon(True)      | Jon(True)     |
# +--------------+-----+----------------+---------------+
# | Samwell      | ... | Samwell(False) | Samwell(True) |
# +--------------+-----+----------------+---------------+
# | Grenn(False) | ... | 0.5            | 0.5           |
# +--------------+-----+----------------+---------------+
# | Grenn(True)  | ... | 0.5            | 0.5           |
# +--------------+-----+----------------+---------------+
# [bnlearn] >CPD of Samwell:
# +----------------+-----+------------------+
# | Aemon          | ... | Aemon(True)      |
# +----------------+-----+------------------+
# | Bran           | ... | Bran(True)       |
# +----------------+-----+------------------+
# | Jojen          | ... | Jojen(True)      |
# +----------------+-----+------------------+
# | Jon            | ... | Jon(True)        |
# +----------------+-----+------------------+
# | Meera          | ... | Meera(True)      |
# +----------------+-----+------------------+
# | Melisandre     | ... | Melisandre(True) |
# +----------------+-----+------------------+
# | Stannis        | ... | Stannis(True)    |
# +----------------+-----+------------------+
# | Samwell(False) | ... | 0.5              |
# +----------------+-----+------------------+
# | Samwell(True)  | ... | 0.5              |
# +----------------+-----+------------------+
# [bnlearn] >CPD of Aerys:
# +--------------+----------+
# | Aerys(False) | 0.899136 |
# +--------------+----------+
# | Aerys(True)  | 0.100864 |
# +--------------+----------+
# [bnlearn] >CPD of Jaime:
# +--------------+-----+---------------+---------------+
# | Aerys        | ... | Aerys(True)   | Aerys(True)   |
# +--------------+-----+---------------+---------------+
# | Arya         | ... | Arya(True)    | Arya(True)    |
# +--------------+-----+---------------+---------------+
# | Catelyn      | ... | Catelyn(True) | Catelyn(True) |
# +--------------+-----+---------------+---------------+
# | Cersei       | ... | Cersei(True)  | Cersei(True)  |
# +--------------+-----+---------------+---------------+
# | Eddard       | ... | Eddard(True)  | Eddard(True)  |
# +--------------+-----+---------------+---------------+
# | Robb         | ... | Robb(True)    | Robb(True)    |
# +--------------+-----+---------------+---------------+
# | Sansa        | ... | Sansa(True)   | Sansa(True)   |
# +--------------+-----+---------------+---------------+
# | Tywin        | ... | Tywin(True)   | Tywin(True)   |
# +--------------+-----+---------------+---------------+
# | Walton       | ... | Walton(False) | Walton(True)  |
# +--------------+-----+---------------+---------------+
# | Jaime(False) | ... | 0.5           | 0.5           |
# +--------------+-----+---------------+---------------+
# | Jaime(True)  | ... | 0.5           | 0.5           |
# +--------------+-----+---------------+---------------+
# [bnlearn] >CPD of Robert:
# +---------------+-----+-----------------+
# | Aerys         | ... | Aerys(True)     |
# +---------------+-----+-----------------+
# | Arya          | ... | Arya(True)      |
# +---------------+-----+-----------------+
# | Cersei        | ... | Cersei(True)    |
# +---------------+-----+-----------------+
# | Daenerys      | ... | Daenerys(True)  |
# +---------------+-----+-----------------+
# | Eddard        | ... | Eddard(True)    |
# +---------------+-----+-----------------+
# | Jaime         | ... | Jaime(True)     |
# +---------------+-----+-----------------+
# | Jon           | ... | Jon(True)       |
# +---------------+-----+-----------------+
# | Jon Arryn     | ... | Jon Arryn(True) |
# +---------------+-----+-----------------+
# | Rhaegar       | ... | Rhaegar(True)   |
# +---------------+-----+-----------------+
# | Sandor        | ... | Sandor(True)    |
# +---------------+-----+-----------------+
# | Sansa         | ... | Sansa(True)     |
# +---------------+-----+-----------------+
# | Tyrion        | ... | Tyrion(True)    |
# +---------------+-----+-----------------+
# | Tywin         | ... | Tywin(True)     |
# +---------------+-----+-----------------+
# | Robert(False) | ... | 0.5             |
# +---------------+-----+-----------------+
# | Robert(True)  | ... | 0.5             |
# +---------------+-----+-----------------+
# [bnlearn] >CPD of Tyrion:
# +---------------+-----+----------------+----------------+
# | Aerys         | ... | Aerys(True)    | Aerys(True)    |
# +---------------+-----+----------------+----------------+
# | Arya          | ... | Arya(True)     | Arya(True)     |
# +---------------+-----+----------------+----------------+
# | Catelyn       | ... | Catelyn(True)  | Catelyn(True)  |
# +---------------+-----+----------------+----------------+
# | Cersei        | ... | Cersei(True)   | Cersei(True)   |
# +---------------+-----+----------------+----------------+
# | Jaime         | ... | Jaime(True)    | Jaime(True)    |
# +---------------+-----+----------------+----------------+
# | Joffrey       | ... | Joffrey(True)  | Joffrey(True)  |
# +---------------+-----+----------------+----------------+
# | Lysa          | ... | Lysa(True)     | Lysa(True)     |
# +---------------+-----+----------------+----------------+
# | Myrcella      | ... | Myrcella(True) | Myrcella(True) |
# +---------------+-----+----------------+----------------+
# | Robb          | ... | Robb(True)     | Robb(True)     |
# +---------------+-----+----------------+----------------+
# | Sansa         | ... | Sansa(True)    | Sansa(True)    |
# +---------------+-----+----------------+----------------+
# | Tywin         | ... | Tywin(True)    | Tywin(True)    |
# +---------------+-----+----------------+----------------+
# | Viserys       | ... | Viserys(False) | Viserys(True)  |
# +---------------+-----+----------------+----------------+
# | Tyrion(False) | ... | 0.5            | 0.5            |
# +---------------+-----+----------------+----------------+
# | Tyrion(True)  | ... | 0.5            | 0.5            |
# +---------------+-----+----------------+----------------+
# [bnlearn] >CPD of Tywin:
# +--------------+-----+-------------+-------------+
# | Aerys        | ... | Aerys(True) | Aerys(True) |
# +--------------+-----+-------------+-------------+
# | Lysa         | ... | Lysa(True)  | Lysa(True)  |
# +--------------+-----+-------------+-------------+
# | Robb         | ... | Robb(False) | Robb(True)  |
# +--------------+-----+-------------+-------------+
# | Tywin(False) | ... | 0.5         | 0.5         |
# +--------------+-----+-------------+-------------+
# | Tywin(True)  | ... | 0.5         | 0.5         |
# +--------------+-----+-------------+-------------+
# [bnlearn] >CPD of Alliser:
# +----------------+-----+--------------------+
# | Janos          | ... | Janos(True)        |
# +----------------+-----+--------------------+
# | Jon            | ... | Jon(True)          |
# +----------------+-----+--------------------+
# | Alliser(False) | ... | 0.5155038759689923 |
# +----------------+-----+--------------------+
# | Alliser(True)  | ... | 0.4844961240310077 |
# +----------------+-----+--------------------+
# [bnlearn] >CPD of Mance:
# +--------------+-----+----------------+---------------+
# | Alliser      | ... | Alliser(True)  | Alliser(True) |
# +--------------+-----+----------------+---------------+
# | Janos        | ... | Janos(True)    | Janos(True)   |
# +--------------+-----+----------------+---------------+
# | Jon          | ... | Jon(True)      | Jon(True)     |
# +--------------+-----+----------------+---------------+
# | Samwell      | ... | Samwell(False) | Samwell(True) |
# +--------------+-----+----------------+---------------+
# | Mance(False) | ... | 0.5            | 0.5           |
# +--------------+-----+----------------+---------------+
# | Mance(True)  | ... | 0.5            | 0.5           |
# +--------------+-----+----------------+---------------+
# [bnlearn] >CPD of Amory:
# +--------------+-----------+
# | Amory(False) | 0.905147  |
# +--------------+-----------+
# | Amory(True)  | 0.0948535 |
# +--------------+-----------+
# [bnlearn] >CPD of Oberyn:
# +---------------+-----+---------------+---------------+
# | Amory         | ... | Amory(True)   | Amory(True)   |
# +---------------+-----+---------------+---------------+
# | Gregor        | ... | Gregor(True)  | Gregor(True)  |
# +---------------+-----+---------------+---------------+
# | Joffrey       | ... | Joffrey(True) | Joffrey(True) |
# +---------------+-----+---------------+---------------+
# | Tyrion        | ... | Tyrion(True)  | Tyrion(True)  |
# +---------------+-----+---------------+---------------+
# | Tywin         | ... | Tywin(False)  | Tywin(True)   |
# +---------------+-----+---------------+---------------+
# | Oberyn(False) | ... | 0.5           | 0.5           |
# +---------------+-----+---------------+---------------+
# | Oberyn(True)  | ... | 0.5           | 0.5           |
# +---------------+-----+---------------+---------------+
# [bnlearn] >CPD of Arya:
# +-------------+---------------------+-----+--------------+
# | Eddard      | Eddard(False)       | ... | Eddard(True) |
# +-------------+---------------------+-----+--------------+
# | Robb        | Robb(False)         | ... | Robb(True)   |
# +-------------+---------------------+-----+--------------+
# | Sansa       | Sansa(False)        | ... | Sansa(True)  |
# +-------------+---------------------+-----+--------------+
# | Arya(False) | 0.9242465753424658  | ... | 0.5          |
# +-------------+---------------------+-----+--------------+
# | Arya(True)  | 0.07575342465753425 | ... | 0.5          |
# +-------------+---------------------+-----+--------------+
# [bnlearn] >CPD of Anguy:
# +--------------+-----+---------------------+
# | Arya         | ... | Arya(True)          |
# +--------------+-----+---------------------+
# | Beric        | ... | Beric(True)         |
# +--------------+-----+---------------------+
# | Anguy(False) | ... | 0.5421245421245421  |
# +--------------+-----+---------------------+
# | Anguy(True)  | ... | 0.45787545787545786 |
# +--------------+-----+---------------------+
# [bnlearn] >CPD of Beric:
# +--------------+-----+--------------+
# | Arya         | ... | Arya(True)   |
# +--------------+-----+--------------+
# | Eddard       | ... | Eddard(True) |
# +--------------+-----+--------------+
# | Sandor       | ... | Sandor(True) |
# +--------------+-----+--------------+
# | Beric(False) | ... | 0.5          |
# +--------------+-----+--------------+
# | Beric(True)  | ... | 0.5          |
# +--------------+-----+--------------+
# [bnlearn] >CPD of Bran:
# +-------------+---------------------+-----+---------------+---------------+
# | Arya        | Arya(False)         | ... | Arya(True)    | Arya(True)    |
# +-------------+---------------------+-----+---------------+---------------+
# | Catelyn     | Catelyn(False)      | ... | Catelyn(True) | Catelyn(True) |
# +-------------+---------------------+-----+---------------+---------------+
# | Eddard      | Eddard(False)       | ... | Eddard(True)  | Eddard(True)  |
# +-------------+---------------------+-----+---------------+---------------+
# | Robb        | Robb(False)         | ... | Robb(True)    | Robb(True)    |
# +-------------+---------------------+-----+---------------+---------------+
# | Sansa       | Sansa(False)        | ... | Sansa(False)  | Sansa(True)   |
# +-------------+---------------------+-----+---------------+---------------+
# | Bran(False) | 0.9070934121490238  | ... | 0.5           | 0.5           |
# +-------------+---------------------+-----+---------------+---------------+
# | Bran(True)  | 0.09290658785097612 | ... | 0.5           | 0.5           |
# +-------------+---------------------+-----+---------------+---------------+
# [bnlearn] >CPD of Brynden:
# +----------------+-----+---------------+---------------+
# | Arya           | ... | Arya(True)    | Arya(True)    |
# +----------------+-----+---------------+---------------+
# | Catelyn        | ... | Catelyn(True) | Catelyn(True) |
# +----------------+-----+---------------+---------------+
# | Edmure         | ... | Edmure(True)  | Edmure(True)  |
# +----------------+-----+---------------+---------------+
# | Rickard        | ... | Rickard(True) | Rickard(True) |
# +----------------+-----+---------------+---------------+
# | Robb           | ... | Robb(True)    | Robb(True)    |
# +----------------+-----+---------------+---------------+
# | Tywin          | ... | Tywin(False)  | Tywin(True)   |
# +----------------+-----+---------------+---------------+
# | Brynden(False) | ... | 0.5           | 0.5           |
# +----------------+-----+---------------+---------------+
# | Brynden(True)  | ... | 0.5           | 0.5           |
# +----------------+-----+---------------+---------------+
# [bnlearn] >CPD of Cersei:
# +---------------+-----+---------------+---------------+
# | Arya          | ... | Arya(True)    | Arya(True)    |
# +---------------+-----+---------------+---------------+
# | Catelyn       | ... | Catelyn(True) | Catelyn(True) |
# +---------------+-----+---------------+---------------+
# | Eddard        | ... | Eddard(True)  | Eddard(True)  |
# +---------------+-----+---------------+---------------+
# | Lysa          | ... | Lysa(True)    | Lysa(True)    |
# +---------------+-----+---------------+---------------+
# | Sansa         | ... | Sansa(True)   | Sansa(True)   |
# +---------------+-----+---------------+---------------+
# | Tywin         | ... | Tywin(False)  | Tywin(True)   |
# +---------------+-----+---------------+---------------+
# | Cersei(False) | ... | 0.5           | 0.5           |
# +---------------+-----+---------------+---------------+
# | Cersei(True)  | ... | 0.5           | 0.5           |
# +---------------+-----+---------------+---------------+
# [bnlearn] >CPD of Gendry:
# +---------------+-----+--------------+
# | Arya          | ... | Arya(True)   |
# +---------------+-----+--------------+
# | Beric         | ... | Beric(True)  |
# +---------------+-----+--------------+
# | Sandor        | ... | Sandor(True) |
# +---------------+-----+--------------+
# | Gendry(False) | ... | 0.5          |
# +---------------+-----+--------------+
# | Gendry(True)  | ... | 0.5          |
# +---------------+-----+--------------+
# [bnlearn] >CPD of Gregor:
# +---------------+-----+---------------+---------------+
# | Arya          | ... | Arya(True)    | Arya(True)    |
# +---------------+-----+---------------+---------------+
# | Bronn         | ... | Bronn(True)   | Bronn(True)   |
# +---------------+-----+---------------+---------------+
# | Cersei        | ... | Cersei(True)  | Cersei(True)  |
# +---------------+-----+---------------+---------------+
# | Jaime         | ... | Jaime(True)   | Jaime(True)   |
# +---------------+-----+---------------+---------------+
# | Joffrey       | ... | Joffrey(True) | Joffrey(True) |
# +---------------+-----+---------------+---------------+
# | Tyrion        | ... | Tyrion(True)  | Tyrion(True)  |
# +---------------+-----+---------------+---------------+
# | Tywin         | ... | Tywin(False)  | Tywin(True)   |
# +---------------+-----+---------------+---------------+
# | Gregor(False) | ... | 0.5           | 0.5           |
# +---------------+-----+---------------+---------------+
# | Gregor(True)  | ... | 0.5           | 0.5           |
# +---------------+-----+---------------+---------------+
# [bnlearn] >CPD of Joffrey:
# +----------------+-----+--------------+--------------+
# | Arya           | ... | Arya(True)   | Arya(True)   |
# +----------------+-----+--------------+--------------+
# | Cersei         | ... | Cersei(True) | Cersei(True) |
# +----------------+-----+--------------+--------------+
# | Jaime          | ... | Jaime(True)  | Jaime(True)  |
# +----------------+-----+--------------+--------------+
# | Robb           | ... | Robb(True)   | Robb(True)   |
# +----------------+-----+--------------+--------------+
# | Sansa          | ... | Sansa(True)  | Sansa(True)  |
# +----------------+-----+--------------+--------------+
# | Tywin          | ... | Tywin(False) | Tywin(True)  |
# +----------------+-----+--------------+--------------+
# | Joffrey(False) | ... | 0.5          | 0.5          |
# +----------------+-----+--------------+--------------+
# | Joffrey(True)  | ... | 0.5          | 0.5          |
# +----------------+-----+--------------+--------------+
# [bnlearn] >CPD of Jon:
# +------------+---------------------+-----+--------------+--------------+
# | Arya       | Arya(False)         | ... | Arya(True)   | Arya(True)   |
# +------------+---------------------+-----+--------------+--------------+
# | Bran       | Bran(False)         | ... | Bran(True)   | Bran(True)   |
# +------------+---------------------+-----+--------------+--------------+
# | Eddard     | Eddard(False)       | ... | Eddard(True) | Eddard(True) |
# +------------+---------------------+-----+--------------+--------------+
# | Robb       | Robb(False)         | ... | Robb(True)   | Robb(True)   |
# +------------+---------------------+-----+--------------+--------------+
# | Sansa      | Sansa(False)        | ... | Sansa(False) | Sansa(True)  |
# +------------+---------------------+-----+--------------+--------------+
# | Jon(False) | 0.8649455854676377  | ... | 0.5          | 0.5          |
# +------------+---------------------+-----+--------------+--------------+
# | Jon(True)  | 0.13505441453236233 | ... | 0.5          | 0.5          |
# +------------+---------------------+-----+--------------+--------------+
# [bnlearn] >CPD of Rickon:
# +---------------+-----+--------------+--------------+
# | Arya          | ... | Arya(True)   | Arya(True)   |
# +---------------+-----+--------------+--------------+
# | Bran          | ... | Bran(True)   | Bran(True)   |
# +---------------+-----+--------------+--------------+
# | Eddard        | ... | Eddard(True) | Eddard(True) |
# +---------------+-----+--------------+--------------+
# | Robb          | ... | Robb(True)   | Robb(True)   |
# +---------------+-----+--------------+--------------+
# | Sansa         | ... | Sansa(False) | Sansa(True)  |
# +---------------+-----+--------------+--------------+
# | Rickon(False) | ... | 0.5          | 0.5          |
# +---------------+-----+--------------+--------------+
# | Rickon(True)  | ... | 0.5          | 0.5          |
# +---------------+-----+--------------+--------------+
# [bnlearn] >CPD of Roose:
# +--------------+-----+---------------+---------------+
# | Arya         | ... | Arya(True)    | Arya(True)    |
# +--------------+-----+---------------+---------------+
# | Catelyn      | ... | Catelyn(True) | Catelyn(True) |
# +--------------+-----+---------------+---------------+
# | Robb         | ... | Robb(False)   | Robb(True)    |
# +--------------+-----+---------------+---------------+
# | Roose(False) | ... | 0.5           | 0.5           |
# +--------------+-----+---------------+---------------+
# | Roose(True)  | ... | 0.5           | 0.5           |
# +--------------+-----+---------------+---------------+
# [bnlearn] >CPD of Sandor:
# +---------------+-----+---------------+---------------+
# | Arya          | ... | Arya(True)    | Arya(True)    |
# +---------------+-----+---------------+---------------+
# | Cersei        | ... | Cersei(True)  | Cersei(True)  |
# +---------------+-----+---------------+---------------+
# | Eddard        | ... | Eddard(True)  | Eddard(True)  |
# +---------------+-----+---------------+---------------+
# | Gregor        | ... | Gregor(True)  | Gregor(True)  |
# +---------------+-----+---------------+---------------+
# | Joffrey       | ... | Joffrey(True) | Joffrey(True) |
# +---------------+-----+---------------+---------------+
# | Sansa         | ... | Sansa(True)   | Sansa(True)   |
# +---------------+-----+---------------+---------------+
# | Tyrion        | ... | Tyrion(False) | Tyrion(True)  |
# +---------------+-----+---------------+---------------+
# | Sandor(False) | ... | 0.5           | 0.5           |
# +---------------+-----+---------------+---------------+
# | Sandor(True)  | ... | 0.5           | 0.5           |
# +---------------+-----+---------------+---------------+
# [bnlearn] >CPD of Thoros:
# +---------------+-----+---------------+--------------+
# | Arya          | ... | Arya(True)    | Arya(True)   |
# +---------------+-----+---------------+--------------+
# | Beric         | ... | Beric(True)   | Beric(True)  |
# +---------------+-----+---------------+--------------+
# | Gendry        | ... | Gendry(True)  | Gendry(True) |
# +---------------+-----+---------------+--------------+
# | Robert        | ... | Robert(True)  | Robert(True) |
# +---------------+-----+---------------+--------------+
# | Sandor        | ... | Sandor(False) | Sandor(True) |
# +---------------+-----+---------------+--------------+
# | Thoros(False) | ... | 0.5           | 0.5          |
# +---------------+-----+---------------+--------------+
# | Thoros(True)  | ... | 0.5           | 0.5          |
# +---------------+-----+---------------+--------------+
# [bnlearn] >CPD of Balon:
# +--------------+-----+---------------+---------------+
# | Jaime        | ... | Jaime(True)   | Jaime(True)   |
# +--------------+-----+---------------+---------------+
# | Robb         | ... | Robb(True)    | Robb(True)    |
# +--------------+-----+---------------+---------------+
# | Stannis      | ... | Stannis(True) | Stannis(True) |
# +--------------+-----+---------------+---------------+
# | Tyrion       | ... | Tyrion(True)  | Tyrion(True)  |
# +--------------+-----+---------------+---------------+
# | Tywin        | ... | Tywin(False)  | Tywin(True)   |
# +--------------+-----+---------------+---------------+
# | Balon(False) | ... | 0.5           | 0.5           |
# +--------------+-----+---------------+---------------+
# | Balon(True)  | ... | 0.5           | 0.5           |
# +--------------+-----+---------------+---------------+
# [bnlearn] >CPD of Loras:
# +--------------+-----+---------------+---------------+
# | Balon        | ... | Balon(True)   | Balon(True)   |
# +--------------+-----+---------------+---------------+
# | Brienne      | ... | Brienne(True) | Brienne(True) |
# +--------------+-----+---------------+---------------+
# | Jaime        | ... | Jaime(True)   | Jaime(True)   |
# +--------------+-----+---------------+---------------+
# | Joffrey      | ... | Joffrey(True) | Joffrey(True) |
# +--------------+-----+---------------+---------------+
# | Renly        | ... | Renly(True)   | Renly(True)   |
# +--------------+-----+---------------+---------------+
# | Sansa        | ... | Sansa(True)   | Sansa(True)   |
# +--------------+-----+---------------+---------------+
# | Tyrion       | ... | Tyrion(False) | Tyrion(True)  |
# +--------------+-----+---------------+---------------+
# | Loras(False) | ... | 0.5           | 0.5           |
# +--------------+-----+---------------+---------------+
# | Loras(True)  | ... | 0.5           | 0.5           |
# +--------------+-----+---------------+---------------+
# [bnlearn] >CPD of Belwas:
# +---------------+-----+--------------------+
# | Daenerys      | ... | Daenerys(True)     |
# +---------------+-----+--------------------+
# | Jorah         | ... | Jorah(True)        |
# +---------------+-----+--------------------+
# | Belwas(False) | ... | 0.5791245791245792 |
# +---------------+-----+--------------------+
# | Belwas(True)  | ... | 0.4208754208754209 |
# +---------------+-----+--------------------+
# [bnlearn] >CPD of Barristan:
# +------------------+-----+----------------+----------------+
# | Belwas           | ... | Belwas(True)   | Belwas(True)   |
# +------------------+-----+----------------+----------------+
# | Daenerys         | ... | Daenerys(True) | Daenerys(True) |
# +------------------+-----+----------------+----------------+
# | Jaime            | ... | Jaime(True)    | Jaime(True)    |
# +------------------+-----+----------------+----------------+
# | Jorah            | ... | Jorah(True)    | Jorah(True)    |
# +------------------+-----+----------------+----------------+
# | Rhaegar          | ... | Rhaegar(True)  | Rhaegar(True)  |
# +------------------+-----+----------------+----------------+
# | Robert           | ... | Robert(False)  | Robert(True)   |
# +------------------+-----+----------------+----------------+
# | Barristan(False) | ... | 0.5            | 0.5            |
# +------------------+-----+----------------+----------------+
# | Barristan(True)  | ... | 0.5            | 0.5            |
# +------------------+-----+----------------+----------------+
# [bnlearn] >CPD of Illyrio:
# +----------------+---------------------+--------------------+
# | Belwas         | Belwas(False)       | Belwas(True)       |
# +----------------+---------------------+--------------------+
# | Illyrio(False) | 0.9474458692453227  | 0.5414462081128748 |
# +----------------+---------------------+--------------------+
# | Illyrio(True)  | 0.05255413075467732 | 0.4585537918871252 |
# +----------------+---------------------+--------------------+
# [bnlearn] >CPD of Hodor:
# +--------------+-----+---------------------+
# | Bran         | ... | Bran(True)          |
# +--------------+-----+---------------------+
# | Robb         | ... | Robb(True)          |
# +--------------+-----+---------------------+
# | Hodor(False) | ... | 0.5421245421245421  |
# +--------------+-----+---------------------+
# | Hodor(True)  | ... | 0.45787545787545786 |
# +--------------+-----+---------------------+
# [bnlearn] >CPD of Jojen:
# +--------------+-----+---------------------+
# | Bran         | ... | Bran(True)          |
# +--------------+-----+---------------------+
# | Hodor        | ... | Hodor(True)         |
# +--------------+-----+---------------------+
# | Jojen(False) | ... | 0.638728323699422   |
# +--------------+-----+---------------------+
# | Jojen(True)  | ... | 0.36127167630057805 |
# +--------------+-----+---------------------+
# [bnlearn] >CPD of Luwin:
# +--------------+---------------------+--------------------+
# | Bran         | Bran(False)         | Bran(True)         |
# +--------------+---------------------+--------------------+
# | Luwin(False) | 0.9433035714285715  | 0.6990521327014217 |
# +--------------+---------------------+--------------------+
# | Luwin(True)  | 0.05669642857142857 | 0.3009478672985782 |
# +--------------+---------------------+--------------------+
# [bnlearn] >CPD of Meera:
# +--------------+-----+-------------+-------------+
# | Bran         | ... | Bran(True)  | Bran(True)  |
# +--------------+-----+-------------+-------------+
# | Hodor        | ... | Hodor(True) | Hodor(True) |
# +--------------+-----+-------------+-------------+
# | Jojen        | ... | Jojen(True) | Jojen(True) |
# +--------------+-----+-------------+-------------+
# | Jon          | ... | Jon(False)  | Jon(True)   |
# +--------------+-----+-------------+-------------+
# | Meera(False) | ... | 0.5         | 0.5         |
# +--------------+-----+-------------+-------------+
# | Meera(True)  | ... | 0.5         | 0.5         |
# +--------------+-----+-------------+-------------+
# [bnlearn] >CPD of Nan:
# +------------+----------------------+-----+--------------------+
# | Bran       | Bran(False)          | ... | Bran(True)         |
# +------------+----------------------+-----+--------------------+
# | Luwin      | Luwin(False)         | ... | Luwin(True)        |
# +------------+----------------------+-----+--------------------+
# | Nan(False) | 0.9704212020823474   | ... | 0.5078740157480315 |
# +------------+----------------------+-----+--------------------+
# | Nan(True)  | 0.029578797917652628 | ... | 0.4921259842519685 |
# +------------+----------------------+-----+--------------------+
# [bnlearn] >CPD of Theon:
# +--------------+-----+--------------+--------------+
# | Bran         | ... | Bran(True)   | Bran(True)   |
# +--------------+-----+--------------+--------------+
# | Jon          | ... | Jon(True)    | Jon(True)    |
# +--------------+-----+--------------+--------------+
# | Rickon       | ... | Rickon(True) | Rickon(True) |
# +--------------+-----+--------------+--------------+
# | Robb         | ... | Robb(False)  | Robb(True)   |
# +--------------+-----+--------------+--------------+
# | Theon(False) | ... | 0.5          | 0.5          |
# +--------------+-----+--------------+--------------+
# | Theon(True)  | ... | 0.5          | 0.5          |
# +--------------+-----+--------------+--------------+
# [bnlearn] >CPD of Brienne:
# +----------------+-----+---------------+---------------+
# | Catelyn        | ... | Catelyn(True) | Catelyn(True) |
# +----------------+-----+---------------+---------------+
# | Cersei         | ... | Cersei(True)  | Cersei(True)  |
# +----------------+-----+---------------+---------------+
# | Jaime          | ... | Jaime(True)   | Jaime(True)   |
# +----------------+-----+---------------+---------------+
# | Robb           | ... | Robb(True)    | Robb(True)    |
# +----------------+-----+---------------+---------------+
# | Roose          | ... | Roose(True)   | Roose(True)   |
# +----------------+-----+---------------+---------------+
# | Sansa          | ... | Sansa(False)  | Sansa(True)   |
# +----------------+-----+---------------+---------------+
# | Brienne(False) | ... | 0.5           | 0.5           |
# +----------------+-----+---------------+---------------+
# | Brienne(True)  | ... | 0.5           | 0.5           |
# +----------------+-----+---------------+---------------+
# [bnlearn] >CPD of Bronn:
# +--------------+-----+--------------------+
# | Cersei       | ... | Cersei(True)       |
# +--------------+-----+--------------------+
# | Tyrion       | ... | Tyrion(True)       |
# +--------------+-----+--------------------+
# | Bronn(False) | ... | 0.5777027027027027 |
# +--------------+-----+--------------------+
# | Bronn(True)  | ... | 0.4222972972972973 |
# +--------------+-----+--------------------+
# [bnlearn] >CPD of Podrick:
# +----------------+-----+--------------+--------------+
# | Bronn          | ... | Bronn(True)  | Bronn(True)  |
# +----------------+-----+--------------+--------------+
# | Sansa          | ... | Sansa(True)  | Sansa(True)  |
# +----------------+-----+--------------+--------------+
# | Tyrion         | ... | Tyrion(True) | Tyrion(True) |
# +----------------+-----+--------------+--------------+
# | Tywin          | ... | Tywin(False) | Tywin(True)  |
# +----------------+-----+--------------+--------------+
# | Podrick(False) | ... | 0.5          | 0.5          |
# +----------------+-----+--------------+--------------+
# | Podrick(True)  | ... | 0.5          | 0.5          |
# +----------------+-----+--------------+--------------+
# [bnlearn] >CPD of Lothar:
# +---------------+-----+---------------+---------------+
# | Brynden       | ... | Brynden(True) | Brynden(True) |
# +---------------+-----+---------------+---------------+
# | Edmure        | ... | Edmure(True)  | Edmure(True)  |
# +---------------+-----+---------------+---------------+
# | Robb          | ... | Robb(True)    | Robb(True)    |
# +---------------+-----+---------------+---------------+
# | Walder        | ... | Walder(False) | Walder(True)  |
# +---------------+-----+---------------+---------------+
# | Lothar(False) | ... | 0.5           | 0.5           |
# +---------------+-----+---------------+---------------+
# | Lothar(True)  | ... | 0.5           | 0.5           |
# +---------------+-----+---------------+---------------+
# [bnlearn] >CPD of Walder:
# +---------------+-----+---------------+---------------+
# | Brynden       | ... | Brynden(True) | Brynden(True) |
# +---------------+-----+---------------+---------------+
# | Catelyn       | ... | Catelyn(True) | Catelyn(True) |
# +---------------+-----+---------------+---------------+
# | Edmure        | ... | Edmure(True)  | Edmure(True)  |
# +---------------+-----+---------------+---------------+
# | Robb          | ... | Robb(True)    | Robb(True)    |
# +---------------+-----+---------------+---------------+
# | Tywin         | ... | Tywin(False)  | Tywin(True)   |
# +---------------+-----+---------------+---------------+
# | Walder(False) | ... | 0.5           | 0.5           |
# +---------------+-----+---------------+---------------+
# | Walder(True)  | ... | 0.5           | 0.5           |
# +---------------+-----+---------------+---------------+
# [bnlearn] >CPD of Catelyn:
# +----------------+---------------------+--------------------+
# | Eddard         | Eddard(False)       | Eddard(True)       |
# +----------------+---------------------+--------------------+
# | Catelyn(False) | 0.9090330788804071  | 0.5805921052631579 |
# +----------------+---------------------+--------------------+
# | Catelyn(True)  | 0.09096692111959287 | 0.4194078947368421 |
# +----------------+---------------------+--------------------+
# [bnlearn] >CPD of Edmure:
# +---------------+-----+---------------+---------------+
# | Catelyn       | ... | Catelyn(True) | Catelyn(True) |
# +---------------+-----+---------------+---------------+
# | Hoster        | ... | Hoster(True)  | Hoster(True)  |
# +---------------+-----+---------------+---------------+
# | Jaime         | ... | Jaime(True)   | Jaime(True)   |
# +---------------+-----+---------------+---------------+
# | Robb          | ... | Robb(False)   | Robb(True)    |
# +---------------+-----+---------------+---------------+
# | Edmure(False) | ... | 0.5           | 0.5           |
# +---------------+-----+---------------+---------------+
# | Edmure(True)  | ... | 0.5           | 0.5           |
# +---------------+-----+---------------+---------------+
# [bnlearn] >CPD of Hoster:
# +---------------+-----+--------------------+
# | Catelyn       | ... | Catelyn(True)      |
# +---------------+-----+--------------------+
# | Lysa          | ... | Lysa(True)         |
# +---------------+-----+--------------------+
# | Hoster(False) | ... | 0.5155038759689923 |
# +---------------+-----+--------------------+
# | Hoster(True)  | ... | 0.4844961240310077 |
# +---------------+-----+--------------------+
# [bnlearn] >CPD of Jeyne:
# +--------------+-----+---------------------+
# | Catelyn      | ... | Catelyn(True)       |
# +--------------+-----+---------------------+
# | Robb         | ... | Robb(True)          |
# +--------------+-----+---------------------+
# | Jeyne(False) | ... | 0.5733788395904437  |
# +--------------+-----+---------------------+
# | Jeyne(True)  | ... | 0.42662116040955633 |
# +--------------+-----+---------------------+
# [bnlearn] >CPD of Lysa:
# +-------------+---------------------+-----+-----------------+
# | Catelyn     | Catelyn(False)      | ... | Catelyn(True)   |
# +-------------+---------------------+-----+-----------------+
# | Jon Arryn   | Jon Arryn(False)    | ... | Jon Arryn(True) |
# +-------------+---------------------+-----+-----------------+
# | Sansa       | Sansa(False)        | ... | Sansa(True)     |
# +-------------+---------------------+-----+-----------------+
# | Lysa(False) | 0.9666151069863367  | ... | 0.5             |
# +-------------+---------------------+-----+-----------------+
# | Lysa(True)  | 0.03338489301366331 | ... | 0.5             |
# +-------------+---------------------+-----+-----------------+
# [bnlearn] >CPD of Petyr:
# +--------------+-----+---------------+---------------+
# | Catelyn      | ... | Catelyn(True) | Catelyn(True) |
# +--------------+-----+---------------+---------------+
# | Lysa         | ... | Lysa(True)    | Lysa(True)    |
# +--------------+-----+---------------+---------------+
# | Robb         | ... | Robb(True)    | Robb(True)    |
# +--------------+-----+---------------+---------------+
# | Sansa        | ... | Sansa(True)   | Sansa(True)   |
# +--------------+-----+---------------+---------------+
# | Tyrion       | ... | Tyrion(True)  | Tyrion(True)  |
# +--------------+-----+---------------+---------------+
# | Tywin        | ... | Tywin(True)   | Tywin(True)   |
# +--------------+-----+---------------+---------------+
# | Walder       | ... | Walder(False) | Walder(True)  |
# +--------------+-----+---------------+---------------+
# | Petyr(False) | ... | 0.5           | 0.5           |
# +--------------+-----+---------------+---------------+
# | Petyr(True)  | ... | 0.5           | 0.5           |
# +--------------+-----+---------------+---------------+
# [bnlearn] >CPD of Robb:
# +-------------+---------------------+-----+---------------------+
# | Catelyn     | Catelyn(False)      | ... | Catelyn(True)       |
# +-------------+---------------------+-----+---------------------+
# | Eddard      | Eddard(False)       | ... | Eddard(True)        |
# +-------------+---------------------+-----+---------------------+
# | Robb(False) | 0.9041287613715885  | ... | 0.5098039215686274  |
# +-------------+---------------------+-----+---------------------+
# | Robb(True)  | 0.09587123862841147 | ... | 0.49019607843137253 |
# +-------------+---------------------+-----+---------------------+
# [bnlearn] >CPD of Roslin:
# +---------------+-----+---------------+---------------+
# | Catelyn       | ... | Catelyn(True) | Catelyn(True) |
# +---------------+-----+---------------+---------------+
# | Edmure        | ... | Edmure(True)  | Edmure(True)  |
# +---------------+-----+---------------+---------------+
# | Lothar        | ... | Lothar(True)  | Lothar(True)  |
# +---------------+-----+---------------+---------------+
# | Walder        | ... | Walder(False) | Walder(True)  |
# +---------------+-----+---------------+---------------+
# | Roslin(False) | ... | 0.5           | 0.5           |
# +---------------+-----+---------------+---------------+
# | Roslin(True)  | ... | 0.5           | 0.5           |
# +---------------+-----+---------------+---------------+
# [bnlearn] >CPD of Sansa:
# +--------------+--------------------+-----+---------------+
# | Catelyn      | Catelyn(False)     | ... | Catelyn(True) |
# +--------------+--------------------+-----+---------------+
# | Eddard       | Eddard(False)      | ... | Eddard(True)  |
# +--------------+--------------------+-----+---------------+
# | Robb         | Robb(False)        | ... | Robb(True)    |
# +--------------+--------------------+-----+---------------+
# | Sansa(False) | 0.8925438596491229 | ... | 0.5           |
# +--------------+--------------------+-----+---------------+
# | Sansa(True)  | 0.1074561403508772 | ... | 0.5           |
# +--------------+--------------------+-----+---------------+
# [bnlearn] >CPD of Stannis:
# +----------------+-----+---------------+---------------+
# | Catelyn        | ... | Catelyn(True) | Catelyn(True) |
# +----------------+-----+---------------+---------------+
# | Jaime          | ... | Jaime(True)   | Jaime(True)   |
# +----------------+-----+---------------+---------------+
# | Joffrey        | ... | Joffrey(True) | Joffrey(True) |
# +----------------+-----+---------------+---------------+
# | Jon            | ... | Jon(True)     | Jon(True)     |
# +----------------+-----+---------------+---------------+
# | Robb           | ... | Robb(True)    | Robb(True)    |
# +----------------+-----+---------------+---------------+
# | Robert         | ... | Robert(True)  | Robert(True)  |
# +----------------+-----+---------------+---------------+
# | Tyrion         | ... | Tyrion(True)  | Tyrion(True)  |
# +----------------+-----+---------------+---------------+
# | Tywin          | ... | Tywin(False)  | Tywin(True)   |
# +----------------+-----+---------------+---------------+
# | Stannis(False) | ... | 0.5           | 0.5           |
# +----------------+-----+---------------+---------------+
# | Stannis(True)  | ... | 0.5           | 0.5           |
# +----------------+-----+---------------+---------------+
# [bnlearn] >CPD of Elia:
# +-------------+-----+---------------+---------------+
# | Cersei      | ... | Cersei(True)  | Cersei(True)  |
# +-------------+-----+---------------+---------------+
# | Gregor      | ... | Gregor(True)  | Gregor(True)  |
# +-------------+-----+---------------+---------------+
# | Jaime       | ... | Jaime(True)   | Jaime(True)   |
# +-------------+-----+---------------+---------------+
# | Rhaegar     | ... | Rhaegar(True) | Rhaegar(True) |
# +-------------+-----+---------------+---------------+
# | Tyrion      | ... | Tyrion(False) | Tyrion(True)  |
# +-------------+-----+---------------+---------------+
# | Elia(False) | ... | 0.5           | 0.5           |
# +-------------+-----+---------------+---------------+
# | Elia(True)  | ... | 0.5           | 0.5           |
# +-------------+-----+---------------+---------------+
# [bnlearn] >CPD of Ilyn:
# +-------------+-----+---------------+---------------+
# | Cersei      | ... | Cersei(True)  | Cersei(True)  |
# +-------------+-----+---------------+---------------+
# | Gregor      | ... | Gregor(True)  | Gregor(True)  |
# +-------------+-----+---------------+---------------+
# | Joffrey     | ... | Joffrey(True) | Joffrey(True) |
# +-------------+-----+---------------+---------------+
# | Meryn       | ... | Meryn(True)   | Meryn(True)   |
# +-------------+-----+---------------+---------------+
# | Sandor      | ... | Sandor(True)  | Sandor(True)  |
# +-------------+-----+---------------+---------------+
# | Tyrion      | ... | Tyrion(False) | Tyrion(True)  |
# +-------------+-----+---------------+---------------+
# | Ilyn(False) | ... | 0.5           | 0.5           |
# +-------------+-----+---------------+---------------+
# | Ilyn(True)  | ... | 0.5           | 0.5           |
# +-------------+-----+---------------+---------------+
# [bnlearn] >CPD of Meryn:
# +--------------+-----+---------------+---------------+
# | Cersei       | ... | Cersei(True)  | Cersei(True)  |
# +--------------+-----+---------------+---------------+
# | Gregor       | ... | Gregor(True)  | Gregor(True)  |
# +--------------+-----+---------------+---------------+
# | Jaime        | ... | Jaime(True)   | Jaime(True)   |
# +--------------+-----+---------------+---------------+
# | Joffrey      | ... | Joffrey(True) | Joffrey(True) |
# +--------------+-----+---------------+---------------+
# | Sandor       | ... | Sandor(True)  | Sandor(True)  |
# +--------------+-----+---------------+---------------+
# | Tyrion       | ... | Tyrion(False) | Tyrion(True)  |
# +--------------+-----+---------------+---------------+
# | Meryn(False) | ... | 0.5           | 0.5           |
# +--------------+-----+---------------+---------------+
# | Meryn(True)  | ... | 0.5           | 0.5           |
# +--------------+-----+---------------+---------------+
# [bnlearn] >CPD of Pycelle:
# +----------------+-----+--------------+--------------+
# | Cersei         | ... | Cersei(True) | Cersei(True) |
# +----------------+-----+--------------+--------------+
# | Tyrion         | ... | Tyrion(True) | Tyrion(True) |
# +----------------+-----+--------------+--------------+
# | Tywin          | ... | Tywin(True)  | Tywin(True)  |
# +----------------+-----+--------------+--------------+
# | Varys          | ... | Varys(False) | Varys(True)  |
# +----------------+-----+--------------+--------------+
# | Pycelle(False) | ... | 0.5          | 0.5          |
# +----------------+-----+--------------+--------------+
# | Pycelle(True)  | ... | 0.5          | 0.5          |
# +----------------+-----+--------------+--------------+
# [bnlearn] >CPD of Shae:
# +-------------+---------------------+-----+--------------+
# | Cersei      | Cersei(False)       | ... | Cersei(True) |
# +-------------+---------------------+-----+--------------+
# | Sansa       | Sansa(False)        | ... | Sansa(True)  |
# +-------------+---------------------+-----+--------------+
# | Tyrion      | Tyrion(False)       | ... | Tyrion(True) |
# +-------------+---------------------+-----+--------------+
# | Shae(False) | 0.978267211201867   | ... | 0.5          |
# +-------------+---------------------+-----+--------------+
# | Shae(True)  | 0.02173278879813302 | ... | 0.5          |
# +-------------+---------------------+-----+--------------+
# [bnlearn] >CPD of Varys:
# +--------------+-----+--------------+--------------+
# | Cersei       | ... | Cersei(True) | Cersei(True) |
# +--------------+-----+--------------+--------------+
# | Kevan        | ... | Kevan(True)  | Kevan(True)  |
# +--------------+-----+--------------+--------------+
# | Renly        | ... | Renly(True)  | Renly(True)  |
# +--------------+-----+--------------+--------------+
# | Shae         | ... | Shae(True)   | Shae(True)   |
# +--------------+-----+--------------+--------------+
# | Tyrion       | ... | Tyrion(True) | Tyrion(True) |
# +--------------+-----+--------------+--------------+
# | Tywin        | ... | Tywin(False) | Tywin(True)  |
# +--------------+-----+--------------+--------------+
# | Varys(False) | ... | 0.5          | 0.5          |
# +--------------+-----+--------------+--------------+
# | Varys(True)  | ... | 0.5          | 0.5          |
# +--------------+-----+--------------+--------------+
# [bnlearn] >CPD of Craster:
# +----------------+-----+----------------+---------------+
# | Gilly          | ... | Gilly(True)    | Gilly(True)   |
# +----------------+-----+----------------+---------------+
# | Jon            | ... | Jon(True)      | Jon(True)     |
# +----------------+-----+----------------+---------------+
# | Mance          | ... | Mance(True)    | Mance(True)   |
# +----------------+-----+----------------+---------------+
# | Samwell        | ... | Samwell(False) | Samwell(True) |
# +----------------+-----+----------------+---------------+
# | Craster(False) | ... | 0.5            | 0.5           |
# +----------------+-----+----------------+---------------+
# | Craster(True)  | ... | 0.5            | 0.5           |
# +----------------+-----+----------------+---------------+
# [bnlearn] >CPD of Karl:
# +-------------+---------------------+---------------------+
# | Craster     | Craster(False)      | Craster(True)       |
# +-------------+---------------------+---------------------+
# | Karl(False) | 0.9473573383870288  | 0.5547826086956522  |
# +-------------+---------------------+---------------------+
# | Karl(True)  | 0.05264266161297115 | 0.44521739130434784 |
# +-------------+---------------------+---------------------+
# [bnlearn] >CPD of Daario:
# +---------------+-----+--------------------+
# | Daenerys      | ... | Daenerys(True)     |
# +---------------+-----+--------------------+
# | Jorah         | ... | Jorah(True)        |
# +---------------+-----+--------------------+
# | Daario(False) | ... | 0.5791245791245792 |
# +---------------+-----+--------------------+
# | Daario(True)  | ... | 0.4208754208754209 |
# +---------------+-----+--------------------+
# [bnlearn] >CPD of Drogo:
# +--------------+-----+----------------+----------------+
# | Daario       | ... | Daario(True)   | Daario(True)   |
# +--------------+-----+----------------+----------------+
# | Daenerys     | ... | Daenerys(True) | Daenerys(True) |
# +--------------+-----+----------------+----------------+
# | Irri         | ... | Irri(True)     | Irri(True)     |
# +--------------+-----+----------------+----------------+
# | Jorah        | ... | Jorah(False)   | Jorah(True)    |
# +--------------+-----+----------------+----------------+
# | Drogo(False) | ... | 0.5            | 0.5            |
# +--------------+-----+----------------+----------------+
# | Drogo(True)  | ... | 0.5            | 0.5            |
# +--------------+-----+----------------+----------------+
# [bnlearn] >CPD of Irri:
# +-------------+---------------------+-----+-----------------+
# | Daario      | Daario(False)       | ... | Daario(True)    |
# +-------------+---------------------+-----+-----------------+
# | Daenerys    | Daenerys(False)     | ... | Daenerys(True)  |
# +-------------+---------------------+-----+-----------------+
# | Missandei   | Missandei(False)    | ... | Missandei(True) |
# +-------------+---------------------+-----+-----------------+
# | Irri(False) | 0.9834405527757922  | ... | 0.5             |
# +-------------+---------------------+-----+-----------------+
# | Irri(True)  | 0.01655944722420777 | ... | 0.5             |
# +-------------+---------------------+-----+-----------------+
# [bnlearn] >CPD of Daenerys:
# +-----------------+----------+
# | Daenerys(False) | 0.862509 |
# +-----------------+----------+
# | Daenerys(True)  | 0.137491 |
# +-----------------+----------+
# [bnlearn] >CPD of Aegon:
# +--------------+---------------------+--------------------+
# | Daenerys     | Daenerys(False)     | Daenerys(True)     |
# +--------------+---------------------+--------------------+
# | Aegon(False) | 0.9455574912891986  | 0.6475409836065574 |
# +--------------+---------------------+--------------------+
# ...
# | Salladhor(False) | 0.9472239814228415  | 0.5468483816013628  |
# +------------------+---------------------+---------------------+
# | Salladhor(True)  | 0.05277601857715854 | 0.45315161839863716 |
# +------------------+---------------------+---------------------+
# [bnlearn] >CPD of Eddard:
# +---------------+--------+
# | Eddard(False) | 0.8858 |
# +---------------+--------+
# | Eddard(True)  | 0.1142 |
# +---------------+--------+
# [bnlearn] >CPD of Eddison:
# +----------------+-----+--------------------+
# | Jon            | ... | Jon(True)          |
# +----------------+-----+--------------------+
# | Samwell        | ... | Samwell(True)      |
# +----------------+-----+--------------------+
# | Eddison(False) | ... | 0.5860927152317881 |
# +----------------+-----+--------------------+
# | Eddison(True)  | ... | 0.4139072847682119 |
# +----------------+-----+--------------------+
# [bnlearn] >CPD of Gilly:
# +--------------+-----+---------------+
# | Jon          | ... | Jon(True)     |
# +--------------+-----+---------------+
# | Mance        | ... | Mance(True)   |
# +--------------+-----+---------------+
# | Samwell      | ... | Samwell(True) |
# +--------------+-----+---------------+
# | Gilly(False) | ... | 0.5           |
# +--------------+-----+---------------+
# | Gilly(True)  | ... | 0.5           |
# +--------------+-----+---------------+
# [bnlearn] >CPD of Qyburn:
# +---------------+---------------------+--------------------+
# | Jaime         | Jaime(False)        | Jaime(True)        |
# +---------------+---------------------+--------------------+
# | Qyburn(False) | 0.9438454627133872  | 0.7006880733944955 |
# +---------------+---------------------+--------------------+
# | Qyburn(True)  | 0.05615453728661276 | 0.2993119266055046 |
# +---------------+---------------------+--------------------+
# [bnlearn] >CPD of Renly:
# +--------------+-----+---------------+---------------+
# | Jaime        | ... | Jaime(True)   | Jaime(True)   |
# +--------------+-----+---------------+---------------+
# | Robert       | ... | Robert(True)  | Robert(True)  |
# +--------------+-----+---------------+---------------+
# | Sansa        | ... | Sansa(True)   | Sansa(True)   |
# +--------------+-----+---------------+---------------+
# | Stannis      | ... | Stannis(True) | Stannis(True) |
# +--------------+-----+---------------+---------------+
# | Tyrion       | ... | Tyrion(False) | Tyrion(True)  |
# +--------------+-----+---------------+---------------+
# | Renly(False) | ... | 0.5           | 0.5           |
# +--------------+-----+---------------+---------------+
# | Renly(True)  | ... | 0.5           | 0.5           |
# +--------------+-----+---------------+---------------+
# [bnlearn] >CPD of Tommen:
# +---------------+-----+----------------+----------------+
# | Jaime         | ... | Jaime(True)    | Jaime(True)    |
# +---------------+-----+----------------+----------------+
# | Joffrey       | ... | Joffrey(True)  | Joffrey(True)  |
# +---------------+-----+----------------+----------------+
# | Myrcella      | ... | Myrcella(True) | Myrcella(True) |
# +---------------+-----+----------------+----------------+
# | Tywin         | ... | Tywin(False)   | Tywin(True)    |
# +---------------+-----+----------------+----------------+
# | Tommen(False) | ... | 0.5            | 0.5            |
# +---------------+-----+----------------+----------------+
# | Tommen(True)  | ... | 0.5            | 0.5            |
# +---------------+-----+----------------+----------------+
# [bnlearn] >CPD of Janos:
# +--------------+-----+---------------+
# | Jon          | ... | Jon(True)     |
# +--------------+-----+---------------+
# | Samwell      | ... | Samwell(True) |
# +--------------+-----+---------------+
# | Tyrion       | ... | Tyrion(True)  |
# +--------------+-----+---------------+
# | Janos(False) | ... | 0.5           |
# +--------------+-----+---------------+
# | Janos(True)  | ... | 0.5           |
# +--------------+-----+---------------+
# [bnlearn] >CPD of Bowen:
# +--------------+-----+---------------+
# | Janos        | ... | Janos(True)   |
# +--------------+-----+---------------+
# | Samwell      | ... | Samwell(True) |
# +--------------+-----+---------------+
# | Bowen(False) | ... | 0.51171875    |
# +--------------+-----+---------------+
# | Bowen(True)  | ... | 0.48828125    |
# +--------------+-----+---------------+
# [bnlearn] >CPD of Kevan:
# +--------------+-----+---------------+---------------+
# | Joffrey      | ... | Joffrey(True) | Joffrey(True) |
# +--------------+-----+---------------+---------------+
# | Sansa        | ... | Sansa(True)   | Sansa(True)   |
# +--------------+-----+---------------+---------------+
# | Tyrion       | ... | Tyrion(True)  | Tyrion(True)  |
# +--------------+-----+---------------+---------------+
# | Tywin        | ... | Tywin(False)  | Tywin(True)   |
# +--------------+-----+---------------+---------------+
# | Kevan(False) | ... | 0.5           | 0.5           |
# +--------------+-----+---------------+---------------+
# | Kevan(True)  | ... | 0.5           | 0.5           |
# +--------------+-----+---------------+---------------+
# [bnlearn] >CPD of Margaery:
# +-----------------+-----+---------------+---------------+
# | Joffrey         | ... | Joffrey(True) | Joffrey(True) |
# +-----------------+-----+---------------+---------------+
# | Loras           | ... | Loras(True)   | Loras(True)   |
# +-----------------+-----+---------------+---------------+
# | Podrick         | ... | Podrick(True) | Podrick(True) |
# +-----------------+-----+---------------+---------------+
# | Renly           | ... | Renly(True)   | Renly(True)   |
# +-----------------+-----+---------------+---------------+
# | Sansa           | ... | Sansa(True)   | Sansa(True)   |
# +-----------------+-----+---------------+---------------+
# | Tommen          | ... | Tommen(True)  | Tommen(True)  |
# +-----------------+-----+---------------+---------------+
# | Tyrion          | ... | Tyrion(False) | Tyrion(True)  |
# +-----------------+-----+---------------+---------------+
# | Margaery(False) | ... | 0.5           | 0.5           |
# +-----------------+-----+---------------+---------------+
# | Margaery(True)  | ... | 0.5           | 0.5           |
# +-----------------+-----+---------------+---------------+
# [bnlearn] >CPD of Myrcella:
# +-----------------+-----+---------------------+
# | Joffrey         | ... | Joffrey(True)       |
# +-----------------+-----+---------------------+
# | Sansa           | ... | Sansa(True)         |
# +-----------------+-----+---------------------+
# | Myrcella(False) | ... | 0.5614035087719298  |
# +-----------------+-----+---------------------+
# | Myrcella(True)  | ... | 0.43859649122807015 |
# +-----------------+-----+---------------------+
# [bnlearn] >CPD of Dalla:
# +--------------+-----+-------------+
# | Jon          | ... | Jon(True)   |
# +--------------+-----+-------------+
# | Mance        | ... | Mance(True) |
# +--------------+-----+-------------+
# | Val          | ... | Val(True)   |
# +--------------+-----+-------------+
# | Dalla(False) | ... | 0.5         |
# +--------------+-----+-------------+
# | Dalla(True)  | ... | 0.5         |
# +--------------+-----+-------------+
# [bnlearn] >CPD of Melisandre:
# +-------------------+-----+--------------------+
# | Jon               | ... | Jon(True)          |
# +-------------------+-----+--------------------+
# | Stannis           | ... | Stannis(True)      |
# +-------------------+-----+--------------------+
# | Melisandre(False) | ... | 0.5173745173745173 |
# +-------------------+-----+--------------------+
# | Melisandre(True)  | ... | 0.4826254826254826 |
# +-------------------+-----+--------------------+
# [bnlearn] >CPD of Orell:
# +--------------+----------------------+---------------------+
# | Jon          | Jon(False)           | Jon(True)           |
# +--------------+----------------------+---------------------+
# | Orell(False) | 0.9429484253765404   | 0.7282377919320594  |
# +--------------+----------------------+---------------------+
# | Orell(True)  | 0.057051574623459604 | 0.27176220806794055 |
# +--------------+----------------------+---------------------+
# [bnlearn] >CPD of Qhorin:
# +---------------+-----+-------------------+
# | Jon           | ... | Jon(True)         |
# +---------------+-----+-------------------+
# | Mance         | ... | Mance(True)       |
# +---------------+-----+-------------------+
# | Rattleshirt   | ... | Rattleshirt(True) |
# +---------------+-----+-------------------+
# | Samwell       | ... | Samwell(True)     |
# +---------------+-----+-------------------+
# | Ygritte       | ... | Ygritte(True)     |
# +---------------+-----+-------------------+
# | Qhorin(False) | ... | 0.5               |
# +---------------+-----+-------------------+
# | Qhorin(True)  | ... | 0.5               |
# +---------------+-----+-------------------+
# [bnlearn] >CPD of Rattleshirt:
# +--------------------+-----+---------------+
# | Jon                | ... | Jon(True)     |
# +--------------------+-----+---------------+
# | Mance              | ... | Mance(True)   |
# +--------------------+-----+---------------+
# | Ygritte            | ... | Ygritte(True) |
# +--------------------+-----+---------------+
# | Rattleshirt(False) | ... | 0.5           |
# +--------------------+-----+---------------+
# | Rattleshirt(True)  | ... | 0.5           |
# +--------------------+-----+---------------+
# [bnlearn] >CPD of Styr:
# +-------------+-----+---------------------+
# | Jon         | ... | Jon(True)           |
# +-------------+-----+---------------------+
# | Mance       | ... | Mance(True)         |
# +-------------+-----+---------------------+
# | Styr(False) | ... | 0.6081504702194357  |
# +-------------+-----+---------------------+
# | Styr(True)  | ... | 0.39184952978056425 |
# +-------------+-----+---------------------+
# [bnlearn] >CPD of Val:
# +------------+----------------------+-----+-------------+
# | Jon        | Jon(False)           | ... | Jon(True)   |
# +------------+----------------------+-----+-------------+
# | Mance      | Mance(False)         | ... | Mance(True) |
# +------------+----------------------+-----+-------------+
# | Tywin      | Tywin(False)         | ... | Tywin(True) |
# +------------+----------------------+-----+-------------+
# | Val(False) | 0.9812769396551724   | ... | 0.5         |
# +------------+----------------------+-----+-------------+
# | Val(True)  | 0.018723060344827586 | ... | 0.5         |
# +------------+----------------------+-----+-------------+
# [bnlearn] >CPD of Ygritte:
# +----------------+-----+---------------------+
# | Jon            | ... | Jon(True)           |
# +----------------+-----+---------------------+
# | Mance          | ... | Mance(True)         |
# +----------------+-----+---------------------+
# | Ygritte(False) | ... | 0.6081504702194357  |
# +----------------+-----+---------------------+
# | Ygritte(True)  | ... | 0.39184952978056425 |
# +----------------+-----+---------------------+
# [bnlearn] >CPD of Jon Arryn:
# +------------------+-----------+
# | Jon Arryn(False) | 0.90402   |
# +------------------+-----------+
# | Jon Arryn(True)  | 0.0959805 |
# +------------------+-----------+
# [bnlearn] >CPD of Lancel:
# +---------------+---------------------+--------------------+
# | Kevan         | Kevan(False)        | Kevan(True)        |
# +---------------+---------------------+--------------------+
# | Lancel(False) | 0.9476330121491412  | 0.5327272727272727 |
# +---------------+---------------------+--------------------+
# | Lancel(True)  | 0.05236698785085882 | 0.4672727272727273 |
# +---------------+---------------------+--------------------+
# [bnlearn] >CPD of Olenna:
# +---------------+-----+--------------------+
# | Loras         | ... | Loras(True)        |
# +---------------+-----+--------------------+
# | Sansa         | ... | Sansa(True)        |
# +---------------+-----+--------------------+
# | Olenna(False) | ... | 0.5265151515151515 |
# +---------------+-----+--------------------+
# | Olenna(True)  | ... | 0.4734848484848485 |
# +---------------+-----+--------------------+
# [bnlearn] >CPD of Marillion:
# +------------------+-----+--------------------+
# | Lysa             | ... | Lysa(True)         |
# +------------------+-----+--------------------+
# | Robert Arryn     | ... | Robert Arryn(True) |
# +------------------+-----+--------------------+
# | Sansa            | ... | Sansa(True)        |
# +------------------+-----+--------------------+
# | Marillion(False) | ... | 0.5                |
# +------------------+-----+--------------------+
# | Marillion(True)  | ... | 0.5                |
# +------------------+-----+--------------------+
# [bnlearn] >CPD of Robert Arryn:
# +---------------------+-----+---------------------+
# | Lysa                | ... | Lysa(True)          |
# +---------------------+-----+---------------------+
# | Sansa               | ... | Sansa(True)         |
# +---------------------+-----+---------------------+
# | Robert Arryn(False) | ... | 0.5503597122302158  |
# +---------------------+-----+---------------------+
# | Robert Arryn(True)  | ... | 0.44964028776978415 |
# +---------------------+-----+---------------------+
# [bnlearn] >CPD of Ellaria:
# +----------------+-----+---------------------+
# | Oberyn         | ... | Oberyn(True)        |
# +----------------+-----+---------------------+
# | Tyrion         | ... | Tyrion(True)        |
# +----------------+-----+---------------------+
# | Ellaria(False) | ... | 0.5454545454545454  |
# +----------------+-----+---------------------+
# | Ellaria(True)  | ... | 0.45454545454545453 |
# +----------------+-----+---------------------+
# [bnlearn] >CPD of Mace:
# +-------------+-----+--------------+
# | Oberyn      | ... | Oberyn(True) |
# +-------------+-----+--------------+
# | Tyrion      | ... | Tyrion(True) |
# +-------------+-----+--------------+
# | Tywin       | ... | Tywin(True)  |
# +-------------+-----+--------------+
# | Mace(False) | ... | 0.5          |
# +-------------+-----+--------------+
# | Mace(True)  | ... | 0.5          |
# +-------------+-----+--------------+
# [bnlearn] >CPD of Rickard:
# +----------------+---------------------+---------------------+
# | Robb           | Robb(False)         | Robb(True)          |
# +----------------+---------------------+---------------------+
# | Rickard(False) | 0.9433288710397144  | 0.6947743467933492  |
# +----------------+---------------------+---------------------+
# | Rickard(True)  | 0.05667112896028559 | 0.30522565320665085 |
# +----------------+---------------------+---------------------+
# [bnlearn] >CPD of Ramsay:
# +---------------+----------------------+--------------------+
# | Robb          | Robb(False)          | Robb(True)         |
# +---------------+----------------------+--------------------+
# | Ramsay(False) | 0.9442213297634985   | 0.6983372921615202 |
# +---------------+----------------------+--------------------+
# | Ramsay(True)  | 0.055778670236501564 | 0.3016627078384798 |
# +---------------+----------------------+--------------------+
# [bnlearn] >CPD of Chataya:
# +----------------+-----+--------------------+
# | Shae           | ... | Shae(True)         |
# +----------------+-----+--------------------+
# | Tyrion         | ... | Tyrion(True)       |
# +----------------+-----+--------------------+
# | Chataya(False) | ... | 0.5387453874538746 |
# +----------------+-----+--------------------+
# | Chataya(True)  | ... | 0.4612546125461255 |
# +----------------+-----+--------------------+
# [bnlearn] >CPD of Shireen:
# +----------------+-----------+
# | Shireen(False) | 0.905147  |
# +----------------+-----------+
# | Shireen(True)  | 0.0948535 |
# +----------------+-----------+
# [bnlearn] >CPD of Doran:
# +--------------+---------------------+---------------------+
# | Tyrion       | Tyrion(False)       | Tyrion(True)        |
# +--------------+---------------------+---------------------+
# | Doran(False) | 0.9414930961853498  | 0.7573739295908658  |
# +--------------+---------------------+---------------------+
# | Doran(True)  | 0.05850690381465013 | 0.24262607040913417 |
# +--------------+---------------------+---------------------+
# [bnlearn] >CPD of Walton:
# +---------------+-----------+
# | Walton(False) | 0.904207  |
# +---------------+-----------+
# | Walton(True)  | 0.0957926 |
# +---------------+-----------+
# [bnlearn] >Compute structure scores for model comparison (higher is better).

# %%
# Generate some data based on DAG
# df1 = bn.sampling(model, n=1000)
# Make predictions
# print(query)
query = bn.inference.fit(DAG, variables=['Grenn'], evidence={'Aemon': 1, 'Samwell': 1})
print(query)
query.df
# Out:
# [bnlearn] >Variable Elimination..
# [bnlearn] >Data is stored in [query.df]
# +----+---------+----------+
# |    | Grenn   |        p |
# +====+=========+==========+
# |  0 | False   | 0.578207 |
# +----+---------+----------+
# |  1 | True    | 0.421793 |
# +----+---------+----------+
# +--------------+--------------+
# | Grenn        |   phi(Grenn) |
# +==============+==============+
# | Grenn(False) |       0.5782 |
# +--------------+--------------+
# | Grenn(True)  |       0.4218 |
# +--------------+--------------+
#    Grenn         p
# 0  False  0.578207
# 1   True  0.421793

# %%
# Structure learning on such a huge network will take a lot of time, and with some methods it may even be impossible to compute.
# Lets try to learn it structure for a smaller subset of the columns.
DAG_learned = bn.structure_learning.fit(df.iloc[:, 0:20])
# Out:
# [bnlearn] >Computing best DAG using [hc]
# [bnlearn] >Set scoring type at [bic]
# [bnlearn] >Compute structure scores for model comparison (higher is better).

# %%
# Keep only significant edges
DAG_learned = bn.independence_test(DAG_learned, df, prune=True)
# Out:
# [bnlearn] >Compute edge strength with [chi_square]
# [bnlearn] >Edge [Bran <-> Brynden] [P=0.0519475] is excluded because it was not significant (P<0.05) with [chi_square]

# %%
# Plot the edges for the small network
_ = bn.plot(DAG_learned,
            interactive=True,
            params_interactive={'notebook':True, 'cdn_resources': 'remote', 'filter_menu': True, 'select_menu': True})
# Out:
# [d3blocks] >INFO> Cleaning edge_properties and config parameters..
# [d3blocks] >INFO> Set directed=True to see the markers!
# [d3blocks] >INFO> Keep only edges with weight>0
# [d3blocks] >INFO> Number of unique nodes: 12
# [d3blocks] >INFO> Slider range is set to [0, 10]
# [d3blocks] >INFO> Write to path: [/tmp/tmp9detd1uf/d3graph.html]
# [d3blocks] >INFO> File already exists and will be overwritten: [/tmp/tmp9detd1uf/d3graph.html]
# [d3blocks] >INFO> Number of unique nodes: 12
# [d3blocks] >INFO> Keep only edges with weight>0
# [d3blocks] >INFO> Slider range is set to [0, 10]
# [bnlearn] >Set node properties.
# [bnlearn]> Set edge weights based on the [chi_square] test statistic.
# [bnlearn] >Set edge properties.
# [d3blocks] >INFO> Write to path: [/tmp/tmpbm5rz9lw/bnlearn_causal_network.html]
# [d3blocks] >INFO> File already exists and will be overwritten: [/tmp/tmpbm5rz9lw/bnlearn_causal_network.html]

# %% [markdown]
# **Fin notebook**
